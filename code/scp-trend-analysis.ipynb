# %%
# SDOT Collision 2004-2025 Dataset
# Name: Maisara Mackeen
# Refer to GitHub README for more information

# %%
import pandas as pd

# %%
df = pd.read_csv("./sdot_collision_comp.csv.xz", compression='xz') 
df.head()
# Out:
#    object_id   status  address_type  \
# 0   73437202  Matched         Block
# 1   73437203  Matched  Intersection
# 2   73437204  Matched         Block
# 3   73437205  Matched  Intersection
# 4   73437206  Matched  Intersection
#
#                                            location severity_code  \
# 0  SW MORGAN ST BETWEEN 37TH AVE SW AND 38TH AVE SW             1
# 1                      DENSMORE AVE N AND N 39TH ST             1
# 2         4TH AVE BETWEEN CHERRY ST AND COLUMBIA ST             1
# 3            1ST AV S BR NB AND EAST MARGINAL WAY S             1
# 4                        15TH AVE NW AND NW 53RD ST             2
#
#                     severity_desc collision_type  person_ct  ped_ct  \
# 0  Property Damage Only Collision     Parked Car          3       0
# 1  Property Damage Only Collision         Angles          2       0
# 2  Property Damage Only Collision     Rear Ended          2       0
# 3  Property Damage Only Collision         Angles          2       0
# 4                Injury Collision        Head On          2       0
#
#    ped_cycle_ct  ...  road_cond               light_cond  speeding_ind  \
# 0             0  ...        Dry  Dark - Street Lights On             0
# 1             0  ...        Wet                 Daylight             0
# 2             0  ...        Dry                 Daylight             0
# 3             0  ...        Dry                 Daylight             0
# 4             0  ...        Dry                     Dawn             0
#
#    st_col_code                                        st_col_desc seglane_key  \
# 0         32.0                             One parked--one moving           0
# 1         10.0                                  Entering at angle           0
# 2         13.0  From same direction - both going straight - bo...           0
# 3         10.0                                  Entering at angle           0
# 4         30.0               From opposite direction - all others           0
#
#   crosswalk_key  hit_parked_car_ind source_report_code  \
# 0             0                   0               PTCR
# 1             0                   0               PTCR
# 2             0                   0               PTCR
# 3             0                   0               PTCR
# 4             0                   0               PTCR
#
#                        source_desc
# 0  Police Traffic Collision Report
# 1  Police Traffic Collision Report
# 2  Police Traffic Collision Report
# 3  Police Traffic Collision Report
# 4  Police Traffic Collision Report
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (214902, 32)

# %%
df.columns
# Out:
# Index(['object_id', 'status', 'address_type', 'location', 'severity_code',
#        'severity_desc', 'collision_type', 'person_ct', 'ped_ct',
#        'ped_cycle_ct', 'vehicle_ct', 'injury_ct', 'serious_injury_ct',
#        'fatal_ct', 'inc_date', 'inc_datetime', 'junction_type',
#        'sdot_col_code', 'sdot_col_desc', 'inattention_ind', 'und_infl_ind',
#        'weather', 'road_cond', 'light_cond', 'speeding_ind', 'st_col_code',
#        'st_col_desc', 'seglane_key', 'crosswalk_key', 'hit_parked_car_ind',
#        'source_report_code', 'source_desc'],
#       dtype='object')

# %%
#df['inc_date'] = pd.to_datetime(df['inc_date'], format='%m/%d%Y')
#df['inc_date'].value_counts()

# %%
#df['inc_dttm'] = pd.to_datetime(df['inc_datetime'], format='%m/%d/%Y %I:%M:%S %p')
#df['inc_dttm'] = pd.to_datetime(df['inc_datetime'], format='mixed')
#df['inc_dttm'].value_counts()

# %%
df['collision_type'].value_counts()
# Out:
# collision_type
# Parked Car    48398
# Angles        41110
# Rear Ended    38352
# Other         27639
# Sideswipe     21093
# Left Turn     16014
# Pedestrian     9154
# Cycles         7094
# Right Turn     3376
# Head On        2672
# Name: count, dtype: int64

# %%
df['person_ct'].value_counts()
# Out:
# person_ct
# 2     125284
# 3      41552
# 4      16816
# 1      14159
# 5       7684
# 0       3660
# 6       3131
# 7       1329
# 8        602
# 9        261
# 10       150
# 11        67
# 12        37
# 13        24
# 14        24
# 17        14
# 15        11
# 16         8
# 20         6
# 44         6
# 19         6
# 25         6
# 18         6
# 22         5
# 26         5
# 29         4
# 23         4
# 47         3
# 28         3
# 31         3
# 32         3
# 34         3
# 27         3
# 24         3
# 37         3
# 30         2
# 21         2
# 36         2
# 81         1
# 43         1
# 48         1
# 35         1
# 41         1
# 57         1
# 39         1
# 53         1
# 54         1
# 93         1
# 49         1
# Name: count, dtype: int64
